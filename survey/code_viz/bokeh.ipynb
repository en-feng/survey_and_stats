# %%
from bokeh.io import output_notebook, show
output_notebook()
import pandas as pd
import numpy as np
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_excel("D:\\teaching\\New Media Analysis and User Experience\\survey\\inm.xlsx")

# %%
for i in range(len(df.columns)):
    print(i,df.columns[i])
# Out:
# 0 method
# 1 l_code
# 2 l_design
# 3 l_operation
# 4 l_production
# 5 l_copywriter
# 6 l_market
# 7 l_other
# 8 l_non
# 9 maj_work
# 10 maj_dir
# 11 cap_code
# 12 cap_design
# 13 cap_operation
# 14 cap_production
# 15 cap_copywriter
# 16 cap_market
# 17 ranking
# 18 effort_read
# 19 effort_info
# 20 effort_res
# 21 effort_project
# 22 effort_overall
# 23 sati_code
# 24 sati_design
# 25 sati_operation
# 26 sati_production
# 27 sati_copywriter
# 28 sati_market
# 29 sati_other
# 30 impr_code
# 31 impr_design
# 32 impr_operation
# 33 impr_production
# 34 impr_copywriter
# 35 impr_market
# 36 impr_other
# 37 sati_overall
# 38 grade
# 39 gender
# 40 spending
# 41 high_school_major
# 42 location
# 43 hukou

# %%
def gender(series):
    if series == 1:
        return '男性'
    else:
        return '女性'

def hukou(series):
    if series == 1:
        return '城镇'
    else:
        return '非城镇'

def location (series):
    if series == 1:
        return "非广东地区"
    elif series == 2:
        return "珠三角地区"
    elif series == 3:
        return "粤东"
    elif series == 4:
        return "粤西"
    else:
        return "粤北"

def like(series):
    if series == 1:
        return '喜欢'
    else:
        return '不喜欢'

def impr(series):
    if series == 1:
        return '有提升空间'
    else:
        return '挺好的'

# %%
df.gender = df.gender.apply(gender).astype('category')
# df.gender.value_counts()

df.hukou = df.hukou.apply(hukou).astype('category')
# df.hukou.value_counts()

df.location = df.location.apply(location).astype('category')
# df.location.value_counts()

# %%
df.head(1)
# Out:
#    method  l_code  l_design  l_operation  l_production  l_copywriter  \
# 0       1       0         1            1             1             1
#
#    l_market  l_other  l_non  maj_work  ...  impr_copywriter  impr_market  \
# 0         0        0      0         4  ...                1            1
#
#    impr_other  sati_overall  grade  gender  spending  high_school_major  \
# 0           0             5      3      女性         4                  2
#
#    location  hukou
# 0        粤西     城镇
#
# [1 rows x 44 columns]

# %%
df.iloc[:,1]
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
#      ..
# 75    1
# 76    0
# 77    1
# 78    0
# 79    0
# Name: l_code, Length: 80, dtype: int64

# %%
for i in range(1,9):
    df.iloc[:,i] = df.iloc[:,i].apply(like).astype('category')

# %%
df.filter(regex = "^l_.*")
# Out:
#    l_code l_design l_operation l_production l_copywriter l_market l_other  \
# 0     不喜欢       喜欢          喜欢           喜欢           喜欢      不喜欢     不喜欢
# 1      喜欢      不喜欢          喜欢           喜欢          不喜欢      不喜欢     不喜欢
# 2     不喜欢       喜欢          喜欢           喜欢           喜欢      不喜欢     不喜欢
# 3     不喜欢      不喜欢          喜欢           喜欢           喜欢      不喜欢     不喜欢
# 4     不喜欢       喜欢         不喜欢          不喜欢          不喜欢      不喜欢     不喜欢
# ..    ...      ...         ...          ...          ...      ...     ...
# 75     喜欢      不喜欢         不喜欢           喜欢          不喜欢      不喜欢     不喜欢
# 76    不喜欢      不喜欢          喜欢           喜欢          不喜欢      不喜欢     不喜欢
# 77     喜欢       喜欢          喜欢           喜欢          不喜欢      不喜欢     不喜欢
# 78    不喜欢       喜欢          喜欢           喜欢           喜欢       喜欢     不喜欢
# 79    不喜欢       喜欢          喜欢           喜欢           喜欢       喜欢     不喜欢
#
#    l_non
# 0    不喜欢
# 1    不喜欢
# 2    不喜欢
# 3    不喜欢
# 4    不喜欢
# ..   ...
# 75   不喜欢
# 76   不喜欢
# 77   不喜欢
# 78   不喜欢
# 79   不喜欢
#
# [80 rows x 8 columns]

# %%
df.head(1)
# Out:
#    method l_code l_design l_operation l_production l_copywriter l_market  \
# 0       1    不喜欢       喜欢          喜欢           喜欢           喜欢      不喜欢
#
#   l_other l_non  maj_work  ...  impr_copywriter  impr_market  impr_other  \
# 0     不喜欢   不喜欢         4  ...                1            1           0
#
#    sati_overall  grade  gender  spending  high_school_major  location  hukou
# 0             5      3      女性         4                  2        粤西     城镇
#
# [1 rows x 44 columns]

# %%
for i in range(30,37):
    df.iloc[:,i] = df.iloc[:,i].apply(impr).astype('category')

# %%
df.filter(regex = "^impr_.*")
# Out:
#    impr_code impr_design impr_operation impr_production impr_copywriter  \
# 0        挺好的       有提升空间          有提升空间           有提升空间           有提升空间
# 1      有提升空间       有提升空间            挺好的             挺好的           有提升空间
# 2        挺好的       有提升空间          有提升空间           有提升空间           有提升空间
# 3        挺好的         挺好的          有提升空间           有提升空间           有提升空间
# 4        挺好的       有提升空间            挺好的             挺好的           有提升空间
# ..       ...         ...            ...             ...             ...
# 75     有提升空间         挺好的            挺好的           有提升空间             挺好的
# 76       挺好的       有提升空间          有提升空间             挺好的             挺好的
# 77     有提升空间         挺好的          有提升空间           有提升空间             挺好的
# 78       挺好的       有提升空间            挺好的             挺好的             挺好的
# 79     有提升空间         挺好的          有提升空间           有提升空间             挺好的
#
#    impr_market impr_other
# 0        有提升空间        挺好的
# 1        有提升空间        挺好的
# 2          挺好的        挺好的
# 3          挺好的        挺好的
# 4          挺好的        挺好的
# ..         ...        ...
# 75       有提升空间        挺好的
# 76       有提升空间        挺好的
# 77       有提升空间        挺好的
# 78       有提升空间        挺好的
# 79       有提升空间        挺好的
#
# [80 rows x 7 columns]

# %% [markdown]
# # 直方图

# %%
from bokeh.io import output_file, show
from bokeh.plotting import figure

# output_file("bar_basic.html")

tb_gender = df.gender.value_counts().rename_axis('gender').reset_index(name='counts')

tb_gender

x_data = tb_gender.gender.to_list()
y_data = tb_gender.counts.to_list()

p = figure(x_range=x_data, plot_height=350, title="男女比例",
           toolbar_location=None, tools="")

p.vbar(x=x_data, top=y_data, width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="318426e1-e15f-431c-ac31-3d74c4afd097" data-root-id="1959"></div>

# %% [markdown]
# # 饼图

# %%
tb_location = df["location"].value_counts()
tb_location
# Out:
# 珠三角地区    40
# 粤东       17
# 粤西       10
# 非广东地区     7
# 粤北        6
# Name: location, dtype: int64

# %%
dict_location = tb_location.to_dict()
dict_location
# Out:
# {'珠三角地区': 40, '粤东': 17, '粤西': 10, '非广东地区': 7, '粤北': 6}

# %%
from math import pi

import pandas as pd

from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum

output_file("pie.html")

x = dict_location

# %%
data = pd.Series(x).reset_index(name='value').rename(columns={'index':'location'})
data
# Out:
#   location  value
# 0    珠三角地区     40
# 1       粤东     17
# 2       粤西     10
# 3    非广东地区      7
# 4       粤北      6

# %%
data['angle'] = data['value']/data['value'].sum() * 2*pi
data
# Out:
#   location  value     angle
# 0    珠三角地区     40  3.141593
# 1       粤东     17  1.335177
# 2       粤西     10  0.785398
# 3    非广东地区      7  0.549779
# 4       粤北      6  0.471239

# %%
data['color'] = Category20c[len(x)]
data
# Out:
#   location  value     angle    color
# 0    珠三角地区     40  3.141593  #3182bd
# 1       粤东     17  1.335177  #6baed6
# 2       粤西     10  0.785398  #9ecae1
# 3    非广东地区      7  0.549779  #c6dbef
# 4       粤北      6  0.471239  #e6550d

# %%
p = figure(plot_height=350, title="Pie Chart", toolbar_location=None,
           tools="hover", tooltips="@location: @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='location', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None

show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-bb15d326039c> in <module>
#       4 p.wedge(x=0, y=1, radius=0.4,
#       5         start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
# ----> 6         line_color="white", fill_color='color', legend_field='location', source=data)
#       7
#       8 p.axis.axis_label=None
#
# fakesource in wedge(self, x, y, radius, start_angle, end_angle, direction, **kwargs)
#
# E:\installation\Anaconda\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     855             mglyph_ca = None
#     856
# --> 857         glyph = _make_glyph(glyphclass, kwargs, glyph_ca)
#     858         nsglyph = _make_glyph(glyphclass, kwargs, nsglyph_ca)
#     859         sglyph = _make_glyph(glyphclass, kwargs, sglyph_ca)
#
# E:\installation\Anaconda\lib\site-packages\bokeh\plotting\helpers.py in _make_glyph(glyphclass, kws, extra)
#     396     kws = kws.copy()
#     397     kws.update(extra)
# --> 398     return glyphclass(**kws)
#     399
#     400
#
# E:\installation\Anaconda\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#     305         kwargs.pop("id", None)
#     306
# --> 307         super(Model, self).__init__(**kwargs)
#     308         default_theme.apply_to_model(self)
#     309
#
# E:\installation\Anaconda\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     251
#     252         for name, value in properties.items():
# --> 253             setattr(self, name, value)
#     254
#     255     def __setattr__(self, name, value):
#
# E:\installation\Anaconda\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     286
#     287             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 288                 (name, self.__class__.__name__, text, nice_join(matches)))
#     289
#     290     def __str__(self):
#
# AttributeError: unexpected attribute 'legend_field' to Wedge, possible attributes are direction, end_angle, end_angle_units, fill_alpha, fill_color, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, radius, radius_units, start_angle, start_angle_units, subscribed_events, tags, x or y

# %% [markdown]
# # 可视化散点图

# %% [markdown]
# # 均值比较

# %% [markdown]
# # 堆叠图

# %%
from bokeh.io import output_file, show
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

output_file("bar_dodged.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ['2015', '2016', '2017']

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 3, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits, y_range=(0, 10), plot_height=350, title="Fruit Counts by Year",
           toolbar_location=None, tools="")

p.vbar(x=dodge('fruits', -0.25, range=p.x_range), top='2015', width=0.2, source=source,
       color="#c9d9d3", legend_label="2015")

p.vbar(x=dodge('fruits',  0.0,  range=p.x_range), top='2016', width=0.2, source=source,
       color="#718dbf", legend_label="2016")

p.vbar(x=dodge('fruits',  0.25, range=p.x_range), top='2017', width=0.2, source=source,
       color="#e84d60", legend_label="2017")

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-95f5e94260cf> in <module>
#      20
#      21 p.vbar(x=dodge('fruits', -0.25, range=p.x_range), top='2015', width=0.2, source=source,
# ---> 22        color="#c9d9d3", legend_label="2015")
#      23
#      24 p.vbar(x=dodge('fruits',  0.0,  range=p.x_range), top='2016', width=0.2, source=source,
#
# fakesource in vbar(self, x, width, top, bottom, **kwargs)
#
# E:\installation\Anaconda\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     855             mglyph_ca = None
#     856
# --> 857         glyph = _make_glyph(glyphclass, kwargs, glyph_ca)
#     858         nsglyph = _make_glyph(glyphclass, kwargs, nsglyph_ca)
#     859         sglyph = _make_glyph(glyphclass, kwargs, sglyph_ca)
#
# E:\installation\Anaconda\lib\site-packages\bokeh\plotting\helpers.py in _make_glyph(glyphclass, kws, extra)
#     396     kws = kws.copy()
#     397     kws.update(extra)
# --> 398     return glyphclass(**kws)
#     399
#     400
#
# E:\installation\Anaconda\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#     305         kwargs.pop("id", None)
#     306
# --> 307         super(Model, self).__init__(**kwargs)
#     308         default_theme.apply_to_model(self)
#     309
#
# E:\installation\Anaconda\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     251
#     252         for name, value in properties.items():
# --> 253             setattr(self, name, value)
#     254
#     255     def __setattr__(self, name, value):
#
# E:\installation\Anaconda\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     286
#     287             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 288                 (name, self.__class__.__name__, text, nice_join(matches)))
#     289
#     290     def __str__(self):
#
# AttributeError: unexpected attribute 'legend_label' to VBar, possible attributes are bottom, fill_alpha, fill_color, hatch_alpha, hatch_color, hatch_extra, hatch_pattern, hatch_scale, hatch_weight, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, subscribed_events, tags, top, width or x
